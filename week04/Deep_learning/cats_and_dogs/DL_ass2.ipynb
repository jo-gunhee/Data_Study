# %%
from imageatm.components import DataPrep

dp = DataPrep(
    samples_file = 'data.json',
    image_dir = './cats_and_dogs/train',
    job_dir='./sample_jobdir'
)
dp.run(resize=True)
# Out:
# D:\Anaconda\envs\image-classification\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\Anaconda\envs\image-classification\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\Anaconda\envs\image-classification\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\Anaconda\envs\image-classification\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\Anaconda\envs\image-classification\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\Anaconda\envs\image-classification\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# ****** Running image validation ******
# 100%|█████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:09<00:00, 210.24it/s]
# ****** Running samples validation ******
#
# Class distribution after validation:
# Cat: 1000 (50.0%)
# Dog: 1000 (50.0%)
# Class mapping:
# {0: 'Cat', 1: 'Dog'}
#
# ****** Creating train/val/test sets ******
#
# Split distribution: train: 0.65, val: 0.15, test: 0.2
#
# Partial split distribution: train: 0.65, val: 0.15, test: 0.20
#
# Train set:
# 0: 650 (50.0%)
# 1: 650 (50.0%)
# Val set:
# 0: 150 (50.0%)
# 1: 150 (50.0%)
# Test set:
# 0: 200 (50.0%)
# 1: 200 (50.0%)
#
# ****** Resizing images ******
# 100%|█████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:03<00:00, 510.13it/s]
# Stored 2000 resized images under cats_and_dogs\train_resized
# Changed image directory to cats_and_dogs\train_resized

# %%
from imageatm.components import Training

trainer = Training(dp.image_dir, dp.job_dir, epochs_train_dense=3, epochs_train_all=1)
trainer.run()
# Out:
# Early stopping patience: 6
# Learning rate patience: 2
#
# ****** Train dense layers ******
#
# Epoch 1/3
# 21/21 [==============================] - 204s 10s/step - loss: 1.1273 - acc: 0.5971 - val_loss: 0.3321 - val_acc: 0.8400
#
# Epoch 00001 val_acc improved from -inf to 0.84000,
# saving model to C:\Users\no1gu\Data_study\AI_X_DL\ass02\sample_jobdir\models\model_mobilenet_01_0.840.hdf5
# Epoch 2/3
# 21/21 [==============================] - 198s 9s/step - loss: 0.6111 - acc: 0.7604 - val_loss: 0.1442 - val_acc: 0.9367
#
# Epoch 00002 val_acc improved from 0.84000 to 0.93667,
# saving model to C:\Users\no1gu\Data_study\AI_X_DL\ass02\sample_jobdir\models\model_mobilenet_02_0.937.hdf5
# Epoch 3/3
# 21/21 [==============================] - 179s 9s/step - loss: 0.4637 - acc: 0.8326 - val_loss: 0.1805 - val_acc: 0.9333
#
# Epoch 00003 val_acc did not improve from 0.93667
#
# ****** Train all layers ******
#
# Epoch 4/4
# 21/21 [==============================] - 642s 31s/step - loss: 0.1876 - acc: 0.9314 - val_loss: 0.0846 - val_acc: 0.9733
#
# Epoch 00004 val_acc improved from 0.93667 to 0.97333,
# saving model to C:\Users\no1gu\Data_study\AI_X_DL\ass02\sample_jobdir\models\model_mobilenet_04_0.973.hdf5

# %%
from imageatm.components import Evaluation
e = Evaluation(image_dir=dp.image_dir, job_dir=dp.job_dir)
e.run()
# Out:
# ****** Load model ******
#
# loaded C:\Users\no1gu\Data_study\AI_X_DL\ass02\sample_jobdir\models\model_mobilenet_04_0.973.hdf5
#
# ****** Make prediction on test set ******
#
# 25/25 [==============================] - 47s 2s/step
#
# ****** Plot distribution on test set ******
# ****** Plot classification report ******
#
#    	prec	rec	f1	support
# Cat	0.93	1.00	0.96	200
# Dog	1.00	0.93	0.96	200
# macro avg	0.97	0.96	0.96	400
# weighted avg	0.97	0.96	0.96	400
#
# ****** Plot confusion matrix (recall) ******
# ****** Plot confusion matrix (precision) ******
# ****** Plot correct and wrong examples ******
# Empty list.
